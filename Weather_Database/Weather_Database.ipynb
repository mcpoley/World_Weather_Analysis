# %%
#Import Dependencies 
import os
import sys
sys.path.append(os.path.join(os.path.dirname(sys.path[0])))
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 443

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=860ab2894e489b6f8f740af795dec16b

# %%
# test to make sure the url is valid
city_url=url + "&q=" + "Boston"
city_weather=requests.get(city_url)
if city_weather.status_code==200:
    print(f"City Weather found")
else:
    print(f"City weather not found.")
# Out:
# City Weather found

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | bengkulu
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | fraga
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | menongue
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | swift current
# Processing Record 15 of Set 1 | kharan
# Processing Record 16 of Set 1 | pinotepa nacional
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | tuatapere
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | port blair
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | akhtanizovskaya
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | oranjemund
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | mayumba
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 1 | saldanha
# Processing Record 31 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 1 | hollola
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | cervo
# Processing Record 38 of Set 1 | anadyr
# Processing Record 39 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | norden
# Processing Record 42 of Set 1 | samarai
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | albertville
# Processing Record 45 of Set 1 | kimbe
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | anshun
# Processing Record 48 of Set 1 | roald
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | codrington
# Processing Record 1 of Set 2 | birin
# Processing Record 2 of Set 2 | korla
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | meulaboh
# Processing Record 6 of Set 2 | narsaq
# Processing Record 7 of Set 2 | guatire
# Processing Record 8 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 2 | tingi
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | boqueirao
# Processing Record 12 of Set 2 | vao
# Processing Record 13 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 2 | moree
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | pithoro
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | lorengau
# Processing Record 20 of Set 2 | bandarbeyla
# Processing Record 21 of Set 2 | aklavik
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | deputatskiy
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | klaksvik
# Processing Record 26 of Set 2 | prince rupert
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | dingle
# Processing Record 29 of Set 2 | nome
# Processing Record 30 of Set 2 | aleksandrovskoye
# Processing Record 31 of Set 2 | ostrovnoy
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | ochakiv
# Processing Record 35 of Set 2 | dalvik
# Processing Record 36 of Set 2 | nuevitas
# Processing Record 37 of Set 2 | saint george
# Processing Record 38 of Set 2 | kapaa
# Processing Record 39 of Set 2 | torbay
# Processing Record 40 of Set 2 | sobolevo
# Processing Record 41 of Set 2 | wysokie mazowieckie
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | kabare
# Processing Record 44 of Set 2 | asau
# Processing Record 45 of Set 2 | souillac
# Processing Record 46 of Set 2 | bonthe
# Processing Record 47 of Set 2 | ketchikan
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | manokwari
# Processing Record 1 of Set 3 | cabo san lucas
# Processing Record 2 of Set 3 | alice springs
# Processing Record 3 of Set 3 | hasaki
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | erzin
# Processing Record 6 of Set 3 | patacamaya
# Processing Record 7 of Set 3 | timmins
# Processing Record 8 of Set 3 | khor
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | buin
# Processing Record 11 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 3 | busselton
# Processing Record 13 of Set 3 | moron
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 3 | west odessa
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | akdepe
# Processing Record 19 of Set 3 | mildura
# Processing Record 20 of Set 3 | norman wells
# Processing Record 21 of Set 3 | vila franca do campo
# Processing Record 22 of Set 3 | bathsheba
# Processing Record 23 of Set 3 | solnechnyy
# Processing Record 24 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 25 of Set 3 | waipawa
# Processing Record 26 of Set 3 | rocha
# Processing Record 27 of Set 3 | laguna
# Processing Record 28 of Set 3 | shiraz
# Processing Record 29 of Set 3 | bontang
# Processing Record 30 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | carnarvon
# Processing Record 33 of Set 3 | maarianhamina
# Processing Record 34 of Set 3 | mussomeli
# Processing Record 35 of Set 3 | labuhan
# Processing Record 36 of Set 3 | rio gallegos
# Processing Record 37 of Set 3 | saint-georges
# Processing Record 38 of Set 3 | ulladulla
# Processing Record 39 of Set 3 | trojes
# Processing Record 40 of Set 3 | tunoshna
# Processing Record 41 of Set 3 | bilibino
# Processing Record 42 of Set 3 | atuona
# Processing Record 43 of Set 3 | dikson
# Processing Record 44 of Set 3 | chokurdakh
# Processing Record 45 of Set 3 | airai
# Processing Record 46 of Set 3 | dongli
# Processing Record 47 of Set 3 | mount gambier
# Processing Record 48 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 3 | fulitun
# City not found. Skipping...
# Processing Record 50 of Set 3 | san cristobal
# Processing Record 1 of Set 4 | lagos
# Processing Record 2 of Set 4 | turbat
# Processing Record 3 of Set 4 | smithers
# Processing Record 4 of Set 4 | erdaojiang
# Processing Record 5 of Set 4 | kavieng
# Processing Record 6 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 4 | bathurst
# Processing Record 8 of Set 4 | tautira
# Processing Record 9 of Set 4 | marsh harbour
# Processing Record 10 of Set 4 | portland
# Processing Record 11 of Set 4 | amapa
# Processing Record 12 of Set 4 | gizo
# Processing Record 13 of Set 4 | saint anthony
# Processing Record 14 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 4 | nanchong
# Processing Record 16 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 4 | north bend
# Processing Record 18 of Set 4 | praya
# Processing Record 19 of Set 4 | cidreira
# Processing Record 20 of Set 4 | port moresby
# Processing Record 21 of Set 4 | szczytno
# Processing Record 22 of Set 4 | pacific grove
# Processing Record 23 of Set 4 | arti
# Processing Record 24 of Set 4 | masuguru
# Processing Record 25 of Set 4 | mandera
# Processing Record 26 of Set 4 | codajas
# Processing Record 27 of Set 4 | los llanos de aridane
# Processing Record 28 of Set 4 | tiznit
# Processing Record 29 of Set 4 | praxedis guerrero
# Processing Record 30 of Set 4 | nanortalik
# Processing Record 31 of Set 4 | mahebourg
# Processing Record 32 of Set 4 | kashan
# Processing Record 33 of Set 4 | srednekolymsk
# Processing Record 34 of Set 4 | okhotsk
# Processing Record 35 of Set 4 | shache
# Processing Record 36 of Set 4 | mehamn
# Processing Record 37 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 38 of Set 4 | alihe
# Processing Record 39 of Set 4 | bethel
# Processing Record 40 of Set 4 | katsuura
# Processing Record 41 of Set 4 | matagami
# Processing Record 42 of Set 4 | fortuna
# Processing Record 43 of Set 4 | afrikanda
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | hamilton
# Processing Record 46 of Set 4 | otanche
# Processing Record 47 of Set 4 | torrington
# Processing Record 48 of Set 4 | okha
# Processing Record 49 of Set 4 | raton
# Processing Record 50 of Set 4 | kenai
# Processing Record 1 of Set 5 | touros
# Processing Record 2 of Set 5 | ulaangom
# Processing Record 3 of Set 5 | waddan
# Processing Record 4 of Set 5 | musoma
# Processing Record 5 of Set 5 | port-gentil
# Processing Record 6 of Set 5 | egvekinot
# Processing Record 7 of Set 5 | mulege
# Processing Record 8 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 5 | huancavelica
# Processing Record 11 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 5 | juba
# Processing Record 13 of Set 5 | meadow lake
# Processing Record 14 of Set 5 | rio grande
# Processing Record 15 of Set 5 | taltal
# Processing Record 16 of Set 5 | fairbanks
# Processing Record 17 of Set 5 | alofi
# Processing Record 18 of Set 5 | sitka
# Processing Record 19 of Set 5 | tazovskiy
# Processing Record 20 of Set 5 | ribeira grande
# Processing Record 21 of Set 5 | abu dhabi
# Processing Record 22 of Set 5 | nara
# Processing Record 23 of Set 5 | yagodnoye
# Processing Record 24 of Set 5 | civitanova marche
# Processing Record 25 of Set 5 | verkhnevilyuysk
# Processing Record 26 of Set 5 | hagenow
# Processing Record 27 of Set 5 | shagonar
# Processing Record 28 of Set 5 | pokrovsk
# Processing Record 29 of Set 5 | pedasi
# Processing Record 30 of Set 5 | hobyo
# Processing Record 31 of Set 5 | yenagoa
# Processing Record 32 of Set 5 | yokadouma
# Processing Record 33 of Set 5 | sete
# Processing Record 34 of Set 5 | barbastro
# Processing Record 35 of Set 5 | comodoro rivadavia
# Processing Record 36 of Set 5 | kismayo
# Processing Record 37 of Set 5 | tottori
# Processing Record 38 of Set 5 | zaraza
# Processing Record 39 of Set 5 | onega
# Processing Record 40 of Set 5 | marzuq
# Processing Record 41 of Set 5 | inta
# Processing Record 42 of Set 5 | broken hill
# Processing Record 43 of Set 5 | canatlan
# Processing Record 44 of Set 5 | severo-kurilsk
# Processing Record 45 of Set 5 | carutapera
# Processing Record 46 of Set 5 | lompoc
# Processing Record 47 of Set 5 | leningradskiy
# Processing Record 48 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 5 | skibbereen
# Processing Record 50 of Set 5 | sibolga
# Processing Record 1 of Set 6 | kruisfontein
# Processing Record 2 of Set 6 | upernavik
# Processing Record 3 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 6 | mantua
# Processing Record 5 of Set 6 | mitsamiouli
# Processing Record 6 of Set 6 | opuwo
# Processing Record 7 of Set 6 | kondoa
# Processing Record 8 of Set 6 | portachuelo
# Processing Record 9 of Set 6 | ossora
# Processing Record 10 of Set 6 | chaa-khol
# City not found. Skipping...
# Processing Record 11 of Set 6 | camacha
# Processing Record 12 of Set 6 | bejar
# Processing Record 13 of Set 6 | kununurra
# Processing Record 14 of Set 6 | zomin
# Processing Record 15 of Set 6 | crateus
# Processing Record 16 of Set 6 | bondo
# Processing Record 17 of Set 6 | castro
# Processing Record 18 of Set 6 | shambu
# Processing Record 19 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 6 | morant bay
# Processing Record 21 of Set 6 | tsiroanomandidy
# Processing Record 22 of Set 6 | muscatine
# Processing Record 23 of Set 6 | ejura
# Processing Record 24 of Set 6 | sulphur springs
# Processing Record 25 of Set 6 | roma
# Processing Record 26 of Set 6 | yulara
# Processing Record 27 of Set 6 | berdigestyakh
# Processing Record 28 of Set 6 | ledyard
# Processing Record 29 of Set 6 | pousat
# City not found. Skipping...
# Processing Record 30 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 6 | maniitsoq
# Processing Record 32 of Set 6 | aguimes
# Processing Record 33 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 6 | ouadda
# Processing Record 35 of Set 6 | richards bay
# Processing Record 36 of Set 6 | clyde river
# Processing Record 37 of Set 6 | khatanga
# Processing Record 38 of Set 6 | salalah
# Processing Record 39 of Set 6 | mafinga
# Processing Record 40 of Set 6 | chumikan
# Processing Record 41 of Set 6 | lodja
# Processing Record 42 of Set 6 | vestmannaeyjar
# Processing Record 43 of Set 6 | sayansk
# Processing Record 44 of Set 6 | belmonte
# Processing Record 45 of Set 6 | kamloops
# Processing Record 46 of Set 6 | san jose
# Processing Record 47 of Set 6 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 48 of Set 6 | isangel
# Processing Record 49 of Set 6 | ancud
# Processing Record 50 of Set 6 | pafos
# Processing Record 1 of Set 7 | gat
# Processing Record 2 of Set 7 | vostok
# Processing Record 3 of Set 7 | sao joao da barra
# Processing Record 4 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 7 | sinnamary
# Processing Record 6 of Set 7 | almaty
# Processing Record 7 of Set 7 | cayenne
# Processing Record 8 of Set 7 | rantepao
# Processing Record 9 of Set 7 | pangai
# Processing Record 10 of Set 7 | mtsensk
# Processing Record 11 of Set 7 | mugango
# Processing Record 12 of Set 7 | zhuhai
# Processing Record 13 of Set 7 | constitucion
# Processing Record 14 of Set 7 | general roca
# Processing Record 15 of Set 7 | atambua
# Processing Record 16 of Set 7 | vardo
# Processing Record 17 of Set 7 | antofagasta
# Processing Record 18 of Set 7 | luderitz
# Processing Record 19 of Set 7 | shiyan
# Processing Record 20 of Set 7 | sarakhs
# Processing Record 21 of Set 7 | skovde
# City not found. Skipping...
# Processing Record 22 of Set 7 | am timan
# Processing Record 23 of Set 7 | mayo
# Processing Record 24 of Set 7 | aksarka
# Processing Record 25 of Set 7 | revda
# Processing Record 26 of Set 7 | nemuro
# Processing Record 27 of Set 7 | harper
# Processing Record 28 of Set 7 | wanning
# Processing Record 29 of Set 7 | esmeralda
# Processing Record 30 of Set 7 | georgetown
# Processing Record 31 of Set 7 | mabaruma
# Processing Record 32 of Set 7 | grindavik
# Processing Record 33 of Set 7 | lagunas
# Processing Record 34 of Set 7 | riyadh
# Processing Record 35 of Set 7 | vanavara
# Processing Record 36 of Set 7 | nova odesa
# Processing Record 37 of Set 7 | axim
# Processing Record 38 of Set 7 | barra do garcas
# Processing Record 39 of Set 7 | sistranda
# Processing Record 40 of Set 7 | shakiso
# Processing Record 41 of Set 7 | singkawang
# Processing Record 42 of Set 7 | talnakh
# Processing Record 43 of Set 7 | anloga
# Processing Record 44 of Set 7 | jaguariuna
# Processing Record 45 of Set 7 | chapais
# Processing Record 46 of Set 7 | naryshkino
# Processing Record 47 of Set 7 | ngaoundere
# Processing Record 48 of Set 7 | sao filipe
# Processing Record 49 of Set 7 | kaseda
# Processing Record 50 of Set 7 | inhambane
# Processing Record 1 of Set 8 | longyearbyen
# Processing Record 2 of Set 8 | hsinchu
# Processing Record 3 of Set 8 | gilazi
# City not found. Skipping...
# Processing Record 4 of Set 8 | zhurivka
# Processing Record 5 of Set 8 | hanzhong
# Processing Record 6 of Set 8 | khuzdar
# Processing Record 7 of Set 8 | port hardy
# Processing Record 8 of Set 8 | deh rawud
# City not found. Skipping...
# Processing Record 9 of Set 8 | sandwick
# Processing Record 10 of Set 8 | eirunepe
# Processing Record 11 of Set 8 | tatawin
# Processing Record 12 of Set 8 | whitehorse
# Processing Record 13 of Set 8 | nanning
# Processing Record 14 of Set 8 | imbituba
# Processing Record 15 of Set 8 | santa fe
# Processing Record 16 of Set 8 | la roche-sur-yon
# Processing Record 17 of Set 8 | ust-ishim
# Processing Record 18 of Set 8 | bud
# Processing Record 19 of Set 8 | kavaratti
# Processing Record 20 of Set 8 | coihaique
# Processing Record 21 of Set 8 | san carlos de bariloche
# Processing Record 22 of Set 8 | wawa
# Processing Record 23 of Set 8 | natal
# Processing Record 24 of Set 8 | faanui
# Processing Record 25 of Set 8 | sawtell
# Processing Record 26 of Set 8 | goure
# Processing Record 27 of Set 8 | srivardhan
# Processing Record 28 of Set 8 | inirida
# Processing Record 29 of Set 8 | mariental
# Processing Record 30 of Set 8 | padang
# Processing Record 31 of Set 8 | port keats
# Processing Record 32 of Set 8 | daru
# Processing Record 33 of Set 8 | rabo de peixe
# Processing Record 34 of Set 8 | shimoda
# Processing Record 35 of Set 8 | san rafael
# Processing Record 36 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 8 | rumonge
# Processing Record 38 of Set 8 | kilcullen
# Processing Record 39 of Set 8 | tessalit
# Processing Record 40 of Set 8 | lundazi
# Processing Record 41 of Set 8 | bubaque
# Processing Record 42 of Set 8 | brahmapuri
# City not found. Skipping...
# Processing Record 43 of Set 8 | vila velha
# Processing Record 44 of Set 8 | muradnagar
# Processing Record 45 of Set 8 | mandiana
# Processing Record 46 of Set 8 | pevek
# Processing Record 47 of Set 8 | coquimbo
# Processing Record 48 of Set 8 | studena
# Processing Record 49 of Set 8 | kieta
# Processing Record 50 of Set 8 | kitimat
# Processing Record 1 of Set 9 | tuktoyaktuk
# Processing Record 2 of Set 9 | pyay
# Processing Record 3 of Set 9 | victoria
# Processing Record 4 of Set 9 | chengde
# Processing Record 5 of Set 9 | san pedro de macoris
# Processing Record 6 of Set 9 | villefranche-de-rouergue
# Processing Record 7 of Set 9 | eyl
# Processing Record 8 of Set 9 | portales
# Processing Record 9 of Set 9 | vicuna
# Processing Record 10 of Set 9 | toora-khem
# Processing Record 11 of Set 9 | saint-joseph
# Processing Record 12 of Set 9 | meylan
# Processing Record 13 of Set 9 | san quintin
# Processing Record 14 of Set 9 | zhigansk
# Processing Record 15 of Set 9 | tilichiki
# Processing Record 16 of Set 9 | timizart
# Processing Record 17 of Set 9 | starosubkhangulovo
# Processing Record 18 of Set 9 | gigmoto
# Processing Record 19 of Set 9 | whitstable
# Processing Record 20 of Set 9 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 21 of Set 9 | sakakah
# Processing Record 22 of Set 9 | kosh-agach
# Processing Record 23 of Set 9 | ormara
# Processing Record 24 of Set 9 | gamba
# Processing Record 25 of Set 9 | atbasar
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | paamiut
# Processing Record 28 of Set 9 | yablonovo
# Processing Record 29 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 30 of Set 9 | viedma
# Processing Record 31 of Set 9 | kaitangata
# Processing Record 32 of Set 9 | byron bay
# Processing Record 33 of Set 9 | namibe
# Processing Record 34 of Set 9 | bobrovka
# Processing Record 35 of Set 9 | trairi
# Processing Record 36 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 37 of Set 9 | kahului
# Processing Record 38 of Set 9 | altay
# Processing Record 39 of Set 9 | santiago
# Processing Record 40 of Set 9 | poya
# Processing Record 41 of Set 9 | leshan
# Processing Record 42 of Set 9 | bagado
# Processing Record 43 of Set 9 | mutsamudu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Albany  42.60  -73.97     21.00        34         100        4.52
# 1       Bengkulu  -3.80  102.27     74.91        91         100        7.34
# 2        Rikitea -23.12 -134.97     78.15        69          42        4.47
# 3        Iqaluit  63.75  -68.51     19.40        79          90        9.17
# 4  Mar Del Plata -38.00  -57.56     55.99        81           0        4.70
# 5      Jamestown  42.10  -79.24     23.00        85          20        5.82
# 6    Yellowknife  62.46 -114.35    -38.20        65          20        6.93
# 7          Fraga  41.52    0.35     41.00       100          34        6.93
# 8     Bredasdorp -34.53   20.04     60.80        77           0        5.99
# 9        Qaanaaq  77.48  -69.36      3.13        71           0        8.66
#
#   Country       Description                 Date
# 0      US   overcast clouds  2020-12-16 05:35:14
# 1      ID   overcast clouds  2020-12-16 05:35:03
# 2      PF  scattered clouds  2020-12-16 05:37:49
# 3      CA        light snow  2020-12-16 05:37:50
# 4      AR         clear sky  2020-12-16 05:37:50
# 5      US        few clouds  2020-12-16 05:34:18
# 6      CA               fog  2020-12-16 05:36:28
# 7      ES  scattered clouds  2020-12-16 05:37:50
# 8      ZA         clear sky  2020-12-16 05:37:50
# 9      GL         clear sky  2020-12-16 05:37:50

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df [new_column_order]
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Albany      US  42.60  -73.97     21.00        34         100
# 1         Bengkulu      ID  -3.80  102.27     74.91        91         100
# 2          Rikitea      PF -23.12 -134.97     78.15        69          42
# 3          Iqaluit      CA  63.75  -68.51     19.40        79          90
# 4    Mar Del Plata      AR -38.00  -57.56     55.99        81           0
# ..             ...     ...    ...     ...       ...       ...         ...
# 398          Altay      CN  47.87   88.12     10.85        80          33
# 399       Santiago      CL -33.46  -70.65     66.00        51           0
# 400           Poya      NC -21.35  165.15     80.58        66          54
# 401         Leshan      CN  29.56  103.76     48.79        65          77
# 402         Bagado      CO   5.41  -76.42     72.01        91         100
#
#      Wind Speed       Description
# 0          4.52   overcast clouds
# 1          7.34   overcast clouds
# 2          4.47  scattered clouds
# 3          9.17        light snow
# 4          4.70         clear sky
# ..          ...               ...
# 398        0.43  scattered clouds
# 399        4.70         clear sky
# 400       11.54     broken clouds
# 401        4.25     broken clouds
# 402        0.60   overcast clouds
#
# [403 rows x 9 columns]

# %%
# Create the output file (CSV).
#output_data_file = "Weather_Database/WeatherPy_Database.csv"
output_data_file=os.path.join(os.getcwd(), "WeatherPy_Database.csv")
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
