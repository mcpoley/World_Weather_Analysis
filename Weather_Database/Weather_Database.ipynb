# %%
#Import Dependencies 
import os
import sys
sys.path.append(os.path.join(os.path.dirname(sys.path[0])))
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 465

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=860ab2894e489b6f8f740af795dec16b

# %%
# test to make sure the url is valid
city_url=url + "&q=" + "Boston"
city_weather=requests.get(city_url)
if city_weather.status_code==200:
    print(f"City Weather found")
else:
    print(f"City weather not found.")
# Out:
# City Weather found

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | tombouctou
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | beringovskiy
# Processing Record 6 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | constitucion
# Processing Record 10 of Set 1 | lucapa
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | haines junction
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | sao miguel do araguaia
# Processing Record 18 of Set 1 | guerrero negro
# Processing Record 19 of Set 1 | marawi
# Processing Record 20 of Set 1 | seoul
# Processing Record 21 of Set 1 | codrington
# Processing Record 22 of Set 1 | saldanha
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | cabo san lucas
# Processing Record 25 of Set 1 | bawku
# Processing Record 26 of Set 1 | yagodnoye
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | birao
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | tanushimaru
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | vanavara
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | kahului
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | privolzhye
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | havre-saint-pierre
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | mount isa
# Processing Record 1 of Set 2 | ritchie
# Processing Record 2 of Set 2 | yashan
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | salalah
# Processing Record 5 of Set 2 | bengkulu
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | jacareacanga
# Processing Record 8 of Set 2 | sheboygan
# Processing Record 9 of Set 2 | waipawa
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | ballina
# Processing Record 12 of Set 2 | xinmin
# Processing Record 13 of Set 2 | norman wells
# Processing Record 14 of Set 2 | pimenta bueno
# Processing Record 15 of Set 2 | hervey bay
# Processing Record 16 of Set 2 | borovoy
# Processing Record 17 of Set 2 | carandai
# Processing Record 18 of Set 2 | laguna
# Processing Record 19 of Set 2 | nemuro
# Processing Record 20 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 2 | mizan teferi
# Processing Record 22 of Set 2 | le port
# Processing Record 23 of Set 2 | batemans bay
# Processing Record 24 of Set 2 | mwandiga
# Processing Record 25 of Set 2 | chokurdakh
# Processing Record 26 of Set 2 | qarqin
# Processing Record 27 of Set 2 | cherskiy
# Processing Record 28 of Set 2 | yining
# Processing Record 29 of Set 2 | kruisfontein
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | kingman
# Processing Record 32 of Set 2 | provideniya
# Processing Record 33 of Set 2 | ambilobe
# Processing Record 34 of Set 2 | sabha
# Processing Record 35 of Set 2 | touros
# Processing Record 36 of Set 2 | kirakira
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | san matias
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | phonhong
# Processing Record 41 of Set 2 | kaitangata
# Processing Record 42 of Set 2 | leningradskiy
# Processing Record 43 of Set 2 | okhotsk
# Processing Record 44 of Set 2 | robe
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | snyder
# Processing Record 47 of Set 2 | la sarre
# Processing Record 48 of Set 2 | lata
# Processing Record 49 of Set 2 | la ronge
# Processing Record 50 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 3 | pangoa
# Processing Record 2 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | las vegas
# Processing Record 6 of Set 3 | disna
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | lagoa
# Processing Record 9 of Set 3 | pitimbu
# Processing Record 10 of Set 3 | dolni bousov
# Processing Record 11 of Set 3 | yulara
# Processing Record 12 of Set 3 | port-gentil
# Processing Record 13 of Set 3 | husavik
# Processing Record 14 of Set 3 | san-pedro
# Processing Record 15 of Set 3 | ilulissat
# Processing Record 16 of Set 3 | arraial do cabo
# Processing Record 17 of Set 3 | marolambo
# Processing Record 18 of Set 3 | isangel
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | nenjiang
# Processing Record 21 of Set 3 | wanning
# Processing Record 22 of Set 3 | dawei
# Processing Record 23 of Set 3 | taoudenni
# Processing Record 24 of Set 3 | baiyin
# Processing Record 25 of Set 3 | thunder bay
# Processing Record 26 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | kapaa
# Processing Record 29 of Set 3 | avarua
# Processing Record 30 of Set 3 | alta floresta
# Processing Record 31 of Set 3 | bluff
# Processing Record 32 of Set 3 | nishihara
# Processing Record 33 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 3 | smithers
# Processing Record 35 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 3 | jardim
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | faya
# Processing Record 39 of Set 3 | skerries
# Processing Record 40 of Set 3 | zachagansk
# City not found. Skipping...
# Processing Record 41 of Set 3 | yar-sale
# Processing Record 42 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 3 | rocha
# Processing Record 45 of Set 3 | meulaboh
# Processing Record 46 of Set 3 | chernyshkovskiy
# Processing Record 47 of Set 3 | jijiga
# Processing Record 48 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 3 | shadrinsk
# Processing Record 50 of Set 3 | altay
# Processing Record 1 of Set 4 | la palma
# Processing Record 2 of Set 4 | tiksi
# Processing Record 3 of Set 4 | dasoguz
# Processing Record 4 of Set 4 | yarega
# Processing Record 5 of Set 4 | tual
# Processing Record 6 of Set 4 | hastings
# Processing Record 7 of Set 4 | meadow lake
# Processing Record 8 of Set 4 | kankon
# Processing Record 9 of Set 4 | seguela
# Processing Record 10 of Set 4 | fortuna
# Processing Record 11 of Set 4 | porto torres
# Processing Record 12 of Set 4 | quimper
# Processing Record 13 of Set 4 | langsa
# Processing Record 14 of Set 4 | changji
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | katsuura
# Processing Record 17 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 4 | kokstad
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | ancud
# Processing Record 21 of Set 4 | kozhva
# Processing Record 22 of Set 4 | rawson
# Processing Record 23 of Set 4 | peniche
# Processing Record 24 of Set 4 | port elizabeth
# Processing Record 25 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | sao joao da barra
# Processing Record 27 of Set 4 | reefton
# City not found. Skipping...
# Processing Record 28 of Set 4 | sumbe
# Processing Record 29 of Set 4 | denpasar
# Processing Record 30 of Set 4 | saint-pierre
# Processing Record 31 of Set 4 | vila franca do campo
# Processing Record 32 of Set 4 | qaanaaq
# Processing Record 33 of Set 4 | wawa
# Processing Record 34 of Set 4 | butaritari
# Processing Record 35 of Set 4 | gao
# Processing Record 36 of Set 4 | svetlyy
# Processing Record 37 of Set 4 | graciano sanchez
# Processing Record 38 of Set 4 | winneba
# Processing Record 39 of Set 4 | auki
# Processing Record 40 of Set 4 | kavieng
# Processing Record 41 of Set 4 | miguel calmon
# Processing Record 42 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 4 | trincomalee
# Processing Record 44 of Set 4 | sistranda
# Processing Record 45 of Set 4 | kattivakkam
# Processing Record 46 of Set 4 | padang
# Processing Record 47 of Set 4 | poum
# Processing Record 48 of Set 4 | byron bay
# Processing Record 49 of Set 4 | georgetown
# Processing Record 50 of Set 4 | keti bandar
# Processing Record 1 of Set 5 | lompoc
# Processing Record 2 of Set 5 | saint-augustin
# Processing Record 3 of Set 5 | mount gambier
# Processing Record 4 of Set 5 | hokitika
# Processing Record 5 of Set 5 | malinovoye ozero
# Processing Record 6 of Set 5 | grand gaube
# Processing Record 7 of Set 5 | sangar
# Processing Record 8 of Set 5 | perelyub
# Processing Record 9 of Set 5 | nkhotakota
# Processing Record 10 of Set 5 | praia da vitoria
# Processing Record 11 of Set 5 | sarkand
# Processing Record 12 of Set 5 | santa rosa
# Processing Record 13 of Set 5 | kholmogory
# Processing Record 14 of Set 5 | poquoson
# Processing Record 15 of Set 5 | palmer
# Processing Record 16 of Set 5 | rawah
# Processing Record 17 of Set 5 | ciudad bolivar
# Processing Record 18 of Set 5 | bud
# Processing Record 19 of Set 5 | kiama
# Processing Record 20 of Set 5 | bagdarin
# Processing Record 21 of Set 5 | port hedland
# Processing Record 22 of Set 5 | japura
# Processing Record 23 of Set 5 | lorengau
# Processing Record 24 of Set 5 | tokzar
# City not found. Skipping...
# Processing Record 25 of Set 5 | halifax
# Processing Record 26 of Set 5 | palafrugell
# Processing Record 27 of Set 5 | ayna
# Processing Record 28 of Set 5 | davila
# Processing Record 29 of Set 5 | hobart
# Processing Record 30 of Set 5 | chiang khong
# Processing Record 31 of Set 5 | kendari
# Processing Record 32 of Set 5 | lukaya
# Processing Record 33 of Set 5 | faanui
# Processing Record 34 of Set 5 | coihaique
# Processing Record 35 of Set 5 | viedma
# Processing Record 36 of Set 5 | anadyr
# Processing Record 37 of Set 5 | souillac
# Processing Record 38 of Set 5 | upernavik
# Processing Record 39 of Set 5 | manokwari
# Processing Record 40 of Set 5 | peace river
# Processing Record 41 of Set 5 | mezen
# Processing Record 42 of Set 5 | uray
# Processing Record 43 of Set 5 | sesheke
# Processing Record 44 of Set 5 | margate
# Processing Record 45 of Set 5 | huilong
# Processing Record 46 of Set 5 | brae
# Processing Record 47 of Set 5 | san quintin
# Processing Record 48 of Set 5 | luderitz
# Processing Record 49 of Set 5 | adrar
# Processing Record 50 of Set 5 | salinopolis
# Processing Record 1 of Set 6 | aklavik
# Processing Record 2 of Set 6 | tuatapere
# Processing Record 3 of Set 6 | madang
# Processing Record 4 of Set 6 | dunedin
# Processing Record 5 of Set 6 | caxito
# Processing Record 6 of Set 6 | hermanus
# Processing Record 7 of Set 6 | olafsvik
# Processing Record 8 of Set 6 | comodoro rivadavia
# Processing Record 9 of Set 6 | flinders
# Processing Record 10 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 6 | hofn
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | caravelas
# Processing Record 14 of Set 6 | aitape
# Processing Record 15 of Set 6 | tiarei
# Processing Record 16 of Set 6 | paamiut
# Processing Record 17 of Set 6 | xiashi
# Processing Record 18 of Set 6 | san
# Processing Record 19 of Set 6 | port hardy
# Processing Record 20 of Set 6 | tasiilaq
# Processing Record 21 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 22 of Set 6 | caracollo
# Processing Record 23 of Set 6 | san juan
# Processing Record 24 of Set 6 | mpongwe
# Processing Record 25 of Set 6 | pombas
# Processing Record 26 of Set 6 | ostrovnoy
# Processing Record 27 of Set 6 | pochutla
# Processing Record 28 of Set 6 | ugoofaaru
# Processing Record 29 of Set 6 | marsaxlokk
# Processing Record 30 of Set 6 | kenai
# Processing Record 31 of Set 6 | goderich
# Processing Record 32 of Set 6 | mashhad
# Processing Record 33 of Set 6 | nanortalik
# Processing Record 34 of Set 6 | maningrida
# Processing Record 35 of Set 6 | zwedru
# Processing Record 36 of Set 6 | fukue
# Processing Record 37 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 6 | half moon bay
# Processing Record 39 of Set 6 | vanino
# Processing Record 40 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 6 | sabang
# Processing Record 42 of Set 6 | krasnoselkup
# Processing Record 43 of Set 6 | kharan
# Processing Record 44 of Set 6 | ahuimanu
# Processing Record 45 of Set 6 | prince rupert
# Processing Record 46 of Set 6 | talnakh
# Processing Record 47 of Set 6 | lop buri
# Processing Record 48 of Set 6 | lumeje
# Processing Record 49 of Set 6 | nanning
# Processing Record 50 of Set 6 | heihe
# Processing Record 1 of Set 7 | wuda
# Processing Record 2 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 7 | barcs
# Processing Record 4 of Set 7 | abha
# Processing Record 5 of Set 7 | klaksvik
# Processing Record 6 of Set 7 | elbrus
# Processing Record 7 of Set 7 | muros
# Processing Record 8 of Set 7 | nicoya
# Processing Record 9 of Set 7 | vinh
# Processing Record 10 of Set 7 | lebu
# Processing Record 11 of Set 7 | polessk
# Processing Record 12 of Set 7 | nakusp
# Processing Record 13 of Set 7 | camana
# Processing Record 14 of Set 7 | ternate
# Processing Record 15 of Set 7 | pakokku
# Processing Record 16 of Set 7 | hamilton
# Processing Record 17 of Set 7 | bulgan
# Processing Record 18 of Set 7 | araripina
# Processing Record 19 of Set 7 | te anau
# Processing Record 20 of Set 7 | sao desiderio
# Processing Record 21 of Set 7 | lima
# Processing Record 22 of Set 7 | gat
# Processing Record 23 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 7 | malakal
# Processing Record 25 of Set 7 | lakes entrance
# Processing Record 26 of Set 7 | san cristobal
# Processing Record 27 of Set 7 | santiago del estero
# Processing Record 28 of Set 7 | santa maria
# Processing Record 29 of Set 7 | saint-georges
# Processing Record 30 of Set 7 | taltal
# Processing Record 31 of Set 7 | wageningen
# Processing Record 32 of Set 7 | dutse
# Processing Record 33 of Set 7 | baker city
# Processing Record 34 of Set 7 | witu
# Processing Record 35 of Set 7 | saskylakh
# Processing Record 36 of Set 7 | roma
# Processing Record 37 of Set 7 | port lincoln
# Processing Record 38 of Set 7 | namatanai
# Processing Record 39 of Set 7 | morada nova
# Processing Record 40 of Set 7 | zenzeli
# Processing Record 41 of Set 7 | bull savanna
# Processing Record 42 of Set 7 | iqaluit
# Processing Record 43 of Set 7 | vila velha
# Processing Record 44 of Set 7 | waitati
# Processing Record 45 of Set 7 | olivenza
# Processing Record 46 of Set 7 | kailua
# Processing Record 47 of Set 7 | nome
# Processing Record 48 of Set 7 | charleston
# Processing Record 49 of Set 7 | hasaki
# Processing Record 50 of Set 7 | buala
# Processing Record 1 of Set 8 | vostok
# Processing Record 2 of Set 8 | muisne
# Processing Record 3 of Set 8 | sivas
# Processing Record 4 of Set 8 | poros
# Processing Record 5 of Set 8 | kirkwall
# Processing Record 6 of Set 8 | luwuk
# Processing Record 7 of Set 8 | bara
# Processing Record 8 of Set 8 | zhanakorgan
# Processing Record 9 of Set 8 | diego de almagro
# Processing Record 10 of Set 8 | pingliang
# Processing Record 11 of Set 8 | fereydun kenar
# Processing Record 12 of Set 8 | klang
# Processing Record 13 of Set 8 | pisco
# Processing Record 14 of Set 8 | longkou
# Processing Record 15 of Set 8 | collie
# Processing Record 16 of Set 8 | flin flon
# Processing Record 17 of Set 8 | jaguaribe
# Processing Record 18 of Set 8 | vao
# Processing Record 19 of Set 8 | tynset
# Processing Record 20 of Set 8 | naze
# Processing Record 21 of Set 8 | lasa
# Processing Record 22 of Set 8 | waingapu
# Processing Record 23 of Set 8 | los llanos de aridane
# Processing Record 24 of Set 8 | berlevag
# Processing Record 25 of Set 8 | mahebourg
# Processing Record 26 of Set 8 | batagay
# Processing Record 27 of Set 8 | cruzeiro do oeste
# Processing Record 28 of Set 8 | butembo
# Processing Record 29 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 8 | pietarsaari
# Processing Record 32 of Set 8 | muscat
# Processing Record 33 of Set 8 | chardara
# Processing Record 34 of Set 8 | mezhdurechensk
# Processing Record 35 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 36 of Set 8 | boca do acre
# Processing Record 37 of Set 8 | mackay
# Processing Record 38 of Set 8 | niteroi
# Processing Record 39 of Set 8 | ulyanovo
# City not found. Skipping...
# Processing Record 40 of Set 8 | tahe
# Processing Record 41 of Set 8 | osmena
# Processing Record 42 of Set 8 | vieux-habitants
# Processing Record 43 of Set 8 | ulaanbaatar
# Processing Record 44 of Set 8 | yelniki
# Processing Record 45 of Set 8 | raga
# Processing Record 46 of Set 8 | aquiraz
# Processing Record 47 of Set 8 | latung
# Processing Record 48 of Set 8 | dongkan
# Processing Record 49 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 8 | saint-joseph
# Processing Record 1 of Set 9 | narsaq
# Processing Record 2 of Set 9 | selenduma
# Processing Record 3 of Set 9 | ilhabela
# Processing Record 4 of Set 9 | bac lieu
# Processing Record 5 of Set 9 | noumea
# Processing Record 6 of Set 9 | karasjok
# Processing Record 7 of Set 9 | butte
# Processing Record 8 of Set 9 | alamosa
# Processing Record 9 of Set 9 | harper
# Processing Record 10 of Set 9 | shizunai
# Processing Record 11 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 9 | pella
# Processing Record 13 of Set 9 | asau
# Processing Record 14 of Set 9 | sao filipe
# Processing Record 15 of Set 9 | sindor
# Processing Record 16 of Set 9 | baherden
# Processing Record 17 of Set 9 | niquelandia
# Processing Record 18 of Set 9 | bilma
# Processing Record 19 of Set 9 | mahibadhoo
# Processing Record 20 of Set 9 | cayenne
# Processing Record 21 of Set 9 | ambulu
# Processing Record 22 of Set 9 | vestmannaeyjar
# Processing Record 23 of Set 9 | hamadan
# Processing Record 24 of Set 9 | oranjemund
# Processing Record 25 of Set 9 | awjilah
# Processing Record 26 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 27 of Set 9 | itarema
# Processing Record 28 of Set 9 | clyde river
# Processing Record 29 of Set 9 | amapa
# Processing Record 30 of Set 9 | bodden town
# Processing Record 31 of Set 9 | kamenka
# Processing Record 32 of Set 9 | tarut
# Processing Record 33 of Set 9 | hadrut
# Processing Record 34 of Set 9 | ayan
# Processing Record 35 of Set 9 | farmington
# Processing Record 36 of Set 9 | sorland
# Processing Record 37 of Set 9 | acapulco
# Processing Record 38 of Set 9 | mehamn
# Processing Record 39 of Set 9 | altamira
# Processing Record 40 of Set 9 | tahta
# Processing Record 41 of Set 9 | istisu
# Processing Record 42 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 9 | tecolutla
# Processing Record 44 of Set 9 | muroto
# Processing Record 45 of Set 9 | rexburg
# Processing Record 46 of Set 9 | guatire
# Processing Record 47 of Set 9 | lahaina
# Processing Record 48 of Set 9 | broken hill
# Processing Record 49 of Set 9 | amahai
# Processing Record 50 of Set 9 | mtwango
# Processing Record 1 of Set 10 | pudozh
# Processing Record 2 of Set 10 | ixtapa
# Processing Record 3 of Set 10 | rudnya
# Processing Record 4 of Set 10 | kon tum
# Processing Record 5 of Set 10 | porto walter
# Processing Record 6 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 10 | port blair
# Processing Record 8 of Set 10 | koutsouras
# Processing Record 9 of Set 10 | coquimbo
# Processing Record 10 of Set 10 | vasto
# Processing Record 11 of Set 10 | havelock
# Processing Record 12 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 13 of Set 10 | fare
# Processing Record 14 of Set 10 | cap-aux-meules
# Processing Record 15 of Set 10 | izyaslav
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Bredasdorp -34.53   20.04     51.80        93           0        3.36
# 1       Tombouctou  20.00   -3.00     65.23        25           0        6.35
# 2           Albany  42.60  -73.97     19.40        78          90       11.41
# 3     Beringovskiy  63.05  179.32     21.63        97         100       21.81
# 4     Longyearbyen  78.22   15.64     12.20        61          75       24.16
# 5           Barrow  71.29 -156.79     -9.40        69           1       19.46
# 6     Constitucion -35.33  -72.42     53.11        92          99        4.18
# 7           Lucapa  -8.42   20.74     64.54        98         100        3.62
# 8   Saint-Philippe -21.36   55.77     77.00        78          90        5.82
# 9  Haines Junction  60.75 -137.51     -4.00        83         100        2.91
#
#   Country      Description                 Date
# 0      ZA        clear sky  2020-12-18 03:38:58
# 1      ML        clear sky  2020-12-18 03:38:58
# 2      US  overcast clouds  2020-12-18 03:38:59
# 3      RU             snow  2020-12-18 03:38:59
# 4      SJ    broken clouds  2020-12-18 03:35:25
# 5      US        clear sky  2020-12-18 03:39:00
# 6      CL  overcast clouds  2020-12-18 03:39:00
# 7      AO  overcast clouds  2020-12-18 03:39:00
# 8      RE  overcast clouds  2020-12-18 03:39:00
# 9      CA  overcast clouds  2020-12-18 03:34:32

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df [new_column_order]
# Out:
#                City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bredasdorp      ZA -34.53   20.04     51.80        93           0
# 1        Tombouctou      ML  20.00   -3.00     65.23        25           0
# 2            Albany      US  42.60  -73.97     19.40        78          90
# 3      Beringovskiy      RU  63.05  179.32     21.63        97         100
# 4      Longyearbyen      SJ  78.22   15.64     12.20        61          75
# ..              ...     ...    ...     ...       ...       ...         ...
# 426           Vasto      IT  42.12   14.71     48.00        76          80
# 427        Havelock      US  34.88  -76.90     39.20        93           1
# 428            Fare      PF -16.70 -151.02     80.08        79          83
# 429  Cap-Aux-Meules      CA  47.38  -61.86     28.40        86         100
# 430        Izyaslav      UA  50.12   26.82     33.96        92         100
#
#      Wind Speed      Description
# 0          3.36        clear sky
# 1          6.35        clear sky
# 2         11.41  overcast clouds
# 3         21.81             snow
# 4         24.16    broken clouds
# ..          ...              ...
# 426        5.01    broken clouds
# 427        3.36        clear sky
# 428       14.16       light rain
# 429       12.75  overcast clouds
# 430        4.63  overcast clouds
#
# [431 rows x 9 columns]

# %%
# Create the output file (CSV).
#output_data_file = "Weather_Database/WeatherPy_Database.csv"
output_data_file=os.path.join(os.getcwd(), "WeatherPy_Database.csv")
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
